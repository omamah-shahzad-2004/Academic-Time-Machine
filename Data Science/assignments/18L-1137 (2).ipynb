# %% [markdown]
# Importing all required libraries

# %%
import pandas as pd, numpy as np, plotly.express as px, random, matplotlib.pyplot as plt
from sklearn.decomposition import PCA, KernelPCA
from sklearn.manifold import LocallyLinearEmbedding, TSNE
from sklearn.linear_model import LogisticRegression
from sklearn import svm

# %%
def loadDataset(filepath):
  data = []
  labels = []
  with open(filepath) as file:
    for line in file:
      aux = []
      for x in line.split():
        aux.append(np.uint8(x))
      labels.append(aux.pop())
      data.append(aux)
  return np.array(data), np.array(labels)

# %% [markdown]
# Loading Train Dataset

# %%
train_data, train_labels = loadDataset("./mnist_train_3_4_5_9.txt");
train_data.shape
# Out:
# (19450, 784)

# %% [markdown]
# Loading Validation Dataset

# %%
validation_data, validation_labels = loadDataset("./mnist_validation_3_4_5_9.txt");
validation_data.shape
# Out:
# (3893, 784)

# %% [markdown]
# # Dimension Reduction to 3D

# %% [markdown]
# ## 1. PCA

# %%
pca = PCA(n_components=3)
pca_train_data = pca.fit_transform(train_data)
pca_validation_data = pca.fit_transform(validation_data)

# %% [markdown]
# ## 2. PCA with Kernel

# %%
kernelpca = KernelPCA(n_components=3, kernel="rbf", gamma=0.0433, fit_inverse_transform=True)
kernelpca_train_data = kernelpca.fit_transform(train_data)
kernelpca_validation_data = kernelpca.fit_transform(validation_data)

# %% [markdown]
# ## 3. LLE

# %%
lle_train_data = LocallyLinearEmbedding(n_components=3, n_neighbors=10).fit_transform(train_data)
lle_validation_data = LocallyLinearEmbedding(n_components=3, n_neighbors=10).fit_transform(validation_data)

# %% [markdown]
# ## 4. t-SNE

# %%
tsne_train_data = TSNE(n_components=3, random_state=0).fit_transform(train_data)
tsne_validation_data = TSNE(n_components=3, random_state=0).fit_transform(validation_data)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %% [markdown]
# # 3D Scatterplots of Digits

# %%
def drawScatterplot(data, labels):
  x = []
  y = []
  z = []
  for i in data:
    x.append(i[0])
    y.append(i[1])
    z.append(i[2])
  px.scatter_3d(x=x, y=y, z=z, color=labels).show()

# %% [markdown]
# ## 1. PCA

# %%
drawScatterplot(pca_train_data, train_labels)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fabb0f16-32b9-4101-9fcb-51694a83beaa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fabb0f16-32b9-4101-9fcb-51694a83beaa")) {                    Plotly.newPlot(                        "fabb0f16-32b9-4101-9fcb-51694a83beaa",                        [{"hovertemplate":"color=5<br>x=%{x}<br>y=%{y}<br>z=%{z}<extra></extra>","legendgroup":"5","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"5","scene":"scene","showlegend":true,"x":[-84.90240151169343,-145.7207995849542,-120.85460440548943,410.15382443346687,-58.31824242842272,70.44818155708921,16.360531918608206,-159.470495466403,26.738119290916302,696.3424206350577,30.873021454410665,-338.43092576353683,-12.884566761803983,-212.86201409369983,227.61179760663717,1104.3294867721718,75.49362061581306,52.216061707102945,499.656406923072,915.6204377780502,-382.5445043157015,728.6919058837537,431.3302012159982,-83.65485958386584,476.5854940916914,-515.1545583070789,253.47436293870769,112.49588944569517,207.44979007430553,656.3790593642092,14.01361390611684,-80.07300508582075,202.63484331774944,-122.8058970352683,1069.621602572139,190.47070109513828,1241.6857097916893,-355.3590881265071,1067.097872210559,-231.74032000823397,1257.652316785526,567.55216729991,454.4648932004153,-297.20831726510147,651.0746737158607,840.3980102714412,800.7182583869667,92.14768579206029,901.119847579358,38.52339946674697,905.6841569780516,-399.1167927841372,1233.2546976213775,509.789680344398,477.4815043425996,510.72605167279386,795.9760752868533,-104.67381533272997,476.4155156736721,552.6941929759982,-225.78576061026976,-622.1845529283277,-12.843441351091128,59.848693910431486,482.4237115009068,-135.3931870650389,94.04614166596441,931.2396177156115,-699.4771319507552,843.5713157808766,343.42543854701006,873.0067310583445,-188.1697789877308,-268.48507252613854,681.6696284257903,309.2540161487725,473.82123006412706,686.8898534174976,347.85155750662943,-67.08043956053739,-160.5575671497317,888.0140827340742,531.5759573127228,34.74068261245587,-334.1413029936674,653.0919829790846,-284.3135775037818,76.40612984132181,998.8672969829411,623.0986689854764,166.1458649668449,-492.2500389879041,836.717977102261,262.7703446979209,226.39661440015138,-83.45647114924253,-345.1570784618617,483.3835577291933,69.27671680233676,-340.47564971887584,989.3161287121158,48.70788621570272,729.7957331507657,961.4774190096559,45.32753959552682,446.9748954709728,-2.451156189636075,480.3306349658572,487.8074595056679,245.45355714445142,-298.1795408706851,694.259202022789,-216.10942316893826,-85.06402958610227,795.8788739318085,-113.88405024898991,-131.77125110757552,440.80612366815785,532.0956941940506,1036.11910178858,78.61290494886696,101.6277842313317,967.8781428245956,168.5004614023781,-128.09949840955898,477.54795350864856,424.8318076642962,532.6617718303968,523.903477756675,40.39184430949964,1182.3197302334563,864.9751298879273,242.0317784793415,299.9448672047146,623.8250870175116,661.3604544773673,48.9401171253643,544.8836472200525,547.4415670202139,94.4486624191953,-368.69921857641305,140.32546458651495,715.1951139744474,532.8540863717791,-202.59284357656878,1241.0581692912706,-153.46731738641193,489.01772025622483,616.0747394520157,-428.80339476244524,-73.1106291153356,573.7747294460836,-71.45433362239842,119.91001849105595,694.098749909176,882.2842335663155,-289.6245204970977,118.64814501078638,-326.6223645793943,36.65331653347665,386.73052974148237,478.61495087822925,846.3354776377228,998.706517402449,-246.23017809928393,1069.370976388249,885.2761487045486,100.48093792128107,345.28448079408605,1091.735848174199,-511.4100287723155,286.82624274293767,623.4091128356706,620.5360384134182,274.80388378582404,-326.4092 ...

# %% [markdown]
# ## 2. PCA with Kernel

# %%
drawScatterplot(kernelpca_train_data, train_labels)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="63ebe678-d56d-4bfd-b98a-67b40068bfac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("63ebe678-d56d-4bfd-b98a-67b40068bfac")) {                    Plotly.newPlot(                        "63ebe678-d56d-4bfd-b98a-67b40068bfac",                        [{"hovertemplate":"color=5<br>x=%{x}<br>y=%{y}<br>z=%{z}<extra></extra>","legendgroup":"5","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"5","scene":"scene","showlegend":true,"x":[-0.000432729687492685,-0.0003515210583457626,0.006308487801896098,-0.0004642783567455672,-0.00023188882807361833,-0.00043535651126778746,-0.00028596912941365076,0.0005143237901955876,0.12347811765576504,-1.9475986544685133e-05,0.0002541487539476373,-0.0005696734349775626,-0.000154924632603914,0.000733937754892187,-0.0005911638616672716,-0.000702908521657888,-0.0005920538875151969,-0.0038541807421626196,-0.00021006443074350156,-0.0006786797476941458,0.00025690065314547446,-0.005281894014434805,-6.034679013084972e-05,0.0003684436994555846,-0.0014522505205113532,-0.0007914159245487687,0.0001076290042217556,0.0003191646197432489,0.0003275621223468862,0.00037186205418433317,0.0005320562618678503,-0.000845603995010192,-0.0026176485186785977,-0.00039503266217317466,-0.000607215887057776,0.0018687548672838953,0.0001549197818080915,0.0004040672293607105,0.0027347702882427965,0.00043355439559765083,0.0009621465970087459,-0.0023899540296365663,-0.0009526331253085349,0.0003774371265679787,-0.0015094352296181278,-0.0029837193565945327,-0.0008934656584834154,-0.0002712332850944236,-0.001668313396061687,5.3297238465608494e-05,-0.0005717799028611755,-0.0012759838002517662,-0.0010265002683951408,-0.0013821547330172108,2.096473766778131e-05,-0.0016727405275703529,0.0005789741838604271,-0.0023126186844911367,-0.00018611439184248378,0.00013328551487726536,-0.001158725572158819,-0.00030494130462023337,-0.0007884896334166665,0.0003748356295970165,0.0009311537029619068,-0.0003387208011187064,0.0016020338870759538,0.00034125323657007665,2.5735206728237752e-05,-0.00012436078535881223,8.024682331437671e-05,-7.542214671357268e-05,-0.00024049513230952,0.001895251359521596,0.0009393029229760023,0.00020296376535644417,0.0003533619866022365,1.5377066669465035e-05,-0.003488942744020336,0.00025286917331181024,-0.0007020272987003766,-2.7767895530446728e-05,0.0004835514102230876,-0.00017918367072583186,2.8252229203657495e-05,-0.0017563488664618092,-0.0009186274914726544,-0.0006226664539086268,0.00014266896118013387,-0.00519348638512776,0.00022709587685536758,-0.00016115947506257025,-0.00336880165566268,0.0013155672254244186,-0.0004096516190399427,8.40656617072964e-05,-0.0022220144521870972,-0.0004947887849791905,-0.0004245557401188664,5.079005847913836e-05,-0.0031025619266718254,-0.0009606110075641935,-0.0002063664930694509,-0.0007224615916759506,0.0003300341492066996,-0.000286446498439908,-0.002726870037953925,-0.00014366216131890465,-0.000505433779428202,0.0003274102699092788,1.0207237904961446e-05,-0.005501438041632626,0.0011176276696146228,-0.004002696656741561,0.005370497031101284,-0.000836259409571839,0.00476896724550745,-0.0005831776405166204,-0.0005205669796658967,-0.004805704260743818,-0.004891996576219637,-0.00157951744842068,-0.0014812786901118094,-0.004906751750622739,-0.00031587433091805593,-0.0001394027845483732,-0.003484448984191061,-0.00554080559901003,-0.0002067496259704828,0.0012662724744418481,-0.00021423834429651077,-0.0011227665085273642,0.0015599375221495323,0.0027564289837393244,-0.0019921695927697532,0.00015724443472748352,0.000789247057614491,-0.003574963231449475,0.0006881697260216469,0.002035132487569143,0.000703980332295422,-0.0007718588405351058,-0.002295015890703367,0.0007245938373389586,-0.0007 ...

# %% [markdown]
# ## 3. LLE

# %%
drawScatterplot(lle_train_data, train_labels)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="32b3960a-ef80-40d9-97ae-06a721698af2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("32b3960a-ef80-40d9-97ae-06a721698af2")) {                    Plotly.newPlot(                        "32b3960a-ef80-40d9-97ae-06a721698af2",                        [{"hovertemplate":"color=5<br>x=%{x}<br>y=%{y}<br>z=%{z}<extra></extra>","legendgroup":"5","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"5","scene":"scene","showlegend":true,"x":[-0.018979447844129953,-0.016419743814369354,0.0022760011800505493,-0.005787436573107685,-0.01692149630903285,-0.00730942927891577,-0.0034985299480206036,-0.0060913543463166,-0.01461950334221215,-0.005684340777295018,-0.012296060891812767,-0.002664523687210717,-0.004000626964140374,-0.008244942476025441,-0.006564566490053206,-0.006154329254121261,-0.005610244352826679,-0.0032533962171961174,-0.005880599854499945,-0.006630813131966781,-0.01690575302250199,-0.005750863426906958,-0.004585198541847646,-0.006498627700623935,-0.005309810886308954,-0.017955687202415756,-0.004943964041241427,-0.014781709255749407,-0.00390683747805146,-0.010859455473350387,-0.005299440580264456,-0.00715175488694749,-0.011820016696639953,-0.007517171686911757,-0.005998557985004693,-0.014355655926483015,-0.005887909313580812,-0.016668972935069668,-0.006147058728088728,-0.014882207719326369,-0.005720385612951946,-0.005999962141235682,-0.00792298911886123,-0.015974260898468134,-0.005918773776265038,-0.00546034281556125,-0.005506252213694639,-0.008990859862300696,-0.005758828254681808,-0.009108871734263932,-0.0057415097225994504,-0.01755757759424008,-0.006148716368518802,-0.006984321447578213,-0.00519036883065827,-0.005624722662293572,-0.006159991589993175,-0.017181435610286778,-0.005221097831519419,-0.005608121097671464,-0.01435405301976474,-0.003727178704908526,0.0006444648308335544,-0.01507606214827246,-0.0071246076213357015,-0.014990625790760435,-0.010398063345294908,-0.005581649438958659,-0.0046313064993406304,-0.0057000743587566,-0.005021840772453464,-0.0052247494561494905,-0.0025032488621685,-0.017621253749806616,-0.005435405862285104,-0.004691907312463009,-0.009620043933220647,-0.0058654949525386475,-0.008097276523042098,-0.005550898082168082,-0.01621135402399838,-0.00615964460713349,-0.005004192200142368,-0.014536230012797476,-0.004491282375800442,-0.007515259833952454,-0.004754664983957424,-0.007518426601129277,-0.005900972932202317,-0.005600484578070403,-0.002938355845610014,-0.009143301458312178,-0.007458397808651706,-0.004831083323842816,-0.007482403441217021,-0.00592146878852963,-0.014328349771803667,-0.00551704639961947,-0.01464756267986833,-0.017803507721424604,-0.005807400013987329,-0.00393621901703701,-0.00511855796831579,-0.005766773925201916,-0.00486788605940732,-0.005399079717386925,-0.01490333884860327,-0.005940091613495696,-0.007780285964282499,-0.006612257058447134,-0.007945313912507062,-0.006355366461455746,-0.0175966101669367,-0.00919312373489999,-0.005702890984069094,-0.007831124852418339,-0.018739827424487765,-0.0051556385542068685,-0.010876499452234314,-0.006115787566866743,-0.0096350798658069,-0.004813930355944384,-0.005882790750416405,-0.00449712662578301,-0.01811693249541214,-0.006773983095954341,-0.0068656712764848275,-0.009000033453137452,-0.006698163126492313,-0.0055859368144399145,-0.005840308907438063,-0.005874933828265057,-0.01075571290183884,-0.008787933105056196,-0.005603540997815054,-0.009612251511779905,-0.015863757511164884,-0.005439722996305731,-0.006157804757274118,-0.004758548042292064,-0.011430025827777553,-0.005331932999194714,-0.008781486814741063,-0.006360028859038427,-0.017088754738514244,-0.005826026111818967,-0.007553494646354609,-0.005800442535757331,-0.006342291060804 ...

# %% [markdown]
# ## 4. t-SNE

# %%
drawScatterplot(tsne_train_data, train_labels)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b2470d80-804a-4dfc-a2d2-ef5bad520b6b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2470d80-804a-4dfc-a2d2-ef5bad520b6b")) {                    Plotly.newPlot(                        "b2470d80-804a-4dfc-a2d2-ef5bad520b6b",                        [{"hovertemplate":"color=5<br>x=%{x}<br>y=%{y}<br>z=%{z}<extra></extra>","legendgroup":"5","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"5","scene":"scene","showlegend":true,"x":[12.68165397644043,16.327852249145508,7.211914539337158,10.676520347595215,17.95469856262207,21.17482566833496,9.968564987182617,18.57317352294922,16.973634719848633,11.770992279052734,18.694358825683594,20.920364379882812,13.927528381347656,17.60980987548828,20.27652931213379,11.034102439880371,13.308371543884277,7.651154518127441,16.169178009033203,12.14812183380127,15.537665367126465,10.262480735778809,9.21436595916748,9.749326705932617,4.530760288238525,15.153304100036621,10.14052677154541,15.19184398651123,10.92834758758545,12.360946655273438,13.713000297546387,18.55406951904297,15.189438819885254,19.696044921875,10.270038604736328,20.630355834960938,11.67897891998291,15.449627876281738,11.83043384552002,20.060941696166992,11.320849418640137,15.658380508422852,17.083219528198242,18.677343368530273,5.892638683319092,16.071292877197266,11.73836898803711,19.812850952148438,6.343874454498291,13.646265029907227,11.720233917236328,14.69626522064209,16.305461883544922,10.880147933959961,6.347005367279053,7.354154586791992,7.090874195098877,13.105066299438477,7.054124355316162,4.453673362731934,18.176515579223633,18.506406784057617,7.454702377319336,13.032058715820312,11.679244995117188,16.32801628112793,15.44290542602539,17.945232391357422,17.951290130615234,11.487093925476074,14.905288696289062,12.273728370666504,13.379034042358398,15.614934921264648,6.8440446853637695,10.414002418518066,20.855623245239258,11.297648429870605,14.875207901000977,16.954578399658203,14.596627235412598,11.474665641784668,11.740696907043457,15.325627326965332,19.87117576599121,15.190505981445312,16.18080711364746,19.347238540649414,8.501145362854004,13.52425479888916,7.985751628875732,19.97878074645996,15.150825500488281,7.314943790435791,7.730582237243652,13.600754737854004,12.982845306396484,14.159231185913086,20.087627410888672,13.908451080322266,7.960161209106445,10.793115615844727,12.189434051513672,4.9630608558654785,20.7647647857666,9.584880828857422,19.783288955688477,9.828322410583496,2.4018778800964355,19.72532844543457,17.978229522705078,18.163549423217773,16.15599250793457,21.147565841674805,9.88097095489502,20.707796096801758,12.793721199035645,17.212139129638672,17.647016525268555,11.381900787353516,18.935224533081055,18.829872131347656,10.663863182067871,17.921545028686523,14.427448272705078,11.203988075256348,18.879756927490234,17.793628692626953,23.313034057617188,10.69261646270752,12.189311981201172,12.258011817932129,13.887794494628906,18.89669418334961,11.015448570251465,17.104106903076172,16.914812088012695,14.194581031799316,7.614602088928223,4.4701738357543945,17.124713897705078,13.60698127746582,20.082298278808594,11.424684524536133,16.798099517822266,9.807198524475098,10.186165809631348,3.979137659072876,19.493057250976562,13.147029876708984,16.604202270507812,15.264463424682617,1.6040290594100952,10.18000316619873,10.364419937133789,9.01909065246582,13.189314842224121,6.9651031494140625,22.028594970703125,19.660308837890625,3.8787038326263428,9.984137535095215,9.406717300415039,7.455979347229004,23.962268829345703,8.705025672912598,8.167478561401367,14.437557220458984,16.595073699951172,9.32278060913086,14.63056755065918,22.28183937072754,8.584702491760254,3.67423152923584,19.8738059997558 ...

# %% [markdown]
# Variance Preserved in PCA Transformations

# %%
pca.explained_variance_ratio_
# Out:
# array([0.12679147, 0.08252777, 0.05607866])

# %% [markdown]
# # Reverse Transform 16 Digits Randomly and Visualize Both Original and Reconstructed Digits

# %%
train_data_random = []
labels_random = []
indices = random.sample(range(0, len(train_data)-1), 16)
for i in indices:
  train_data_random.append(train_data[i])
  labels_random.append(train_labels[i])

# %%
def fun(data):
  aux = []
  for i in indices:
    aux.append(data[i])
  return np.array(aux)

# %%
def drawMatplot(data):
  fig, axes = plt.subplots(4, 4, figsize=(10, 10))
  for i in range(16):
    a = data[i].reshape(28, 28)
    ax = axes[i//4, i%4]
    ax.imshow(a, cmap='gray')
    ax.set_title('Label: {}'.format(labels_random[i]))
  plt.tight_layout()
  plt.show()

# %%
drawMatplot(train_data_random)

# %% [markdown]
# ## 1. PCA

# %%
drawMatplot(pca.inverse_transform(fun(pca_train_data)).astype('uint8'))

# %% [markdown]
# ## 2. PCA with Kernel

# %%
drawMatplot(kernelpca.inverse_transform(fun(kernelpca_train_data)).astype('uint8'))

# %% [markdown]
# # Classification on 3D Dataset

# %% [markdown]
# ## 1. Logistic Regression

# %%
def fun2(train_data, train_labels, validation_data, validation_labels, max_iter):
  clf = LogisticRegression(random_state=0, max_iter=max_iter).fit(train_data, train_labels)
  print("Training Accuracy: ", clf.score(train_data, train_labels))
  print("Validation Accuracy: ", clf.score(validation_data, validation_labels))

# %% [markdown]
# ### 1. PCA

# %%
fun2(pca_train_data, train_labels, pca_validation_data, validation_labels, 600)
# Out:
# Training Accuracy:  0.6185089974293059
# Validation Accuracy:  0.6146930387875674

# %% [markdown]
# ### 2. PCA with Kernel

# %%
fun2(kernelpca_train_data, train_labels, kernelpca_validation_data, validation_labels, 400)
# Out:
# Training Accuracy:  0.25974293059125964
# Validation Accuracy:  0.27742101207295145

# %% [markdown]
# ### 3. LLE

# %%
fun2(lle_train_data, train_labels, lle_validation_data, validation_labels, 400)
# Out:
# Training Accuracy:  0.6413881748071979
# Validation Accuracy:  0.6321602876958644

# %% [markdown]
# ### 4. t-SNE

# %%
fun2(tsne_train_data, train_labels, tsne_validation_data, validation_labels, 400)
# Out:
# Training Accuracy:  0.9673007712082262
# Validation Accuracy:  0.6241972771641408

# %% [markdown]
# ## 2. SVM

# %%
def fun3(train_data, train_labels, validation_data, validation_labels, clf):
  clf.fit(train_data, train_labels)
  print("Training Accuracy: ", clf.score(train_data, train_labels))
  print("Validation Accuracy: ", clf.score(validation_data, validation_labels))

# %% [markdown]
# ### 1. PCA

# %%
clf = svm.SVC(kernel='rbf', max_iter = 10000, gamma = 0.001)
fun3(pca_train_data, train_labels, pca_validation_data, validation_labels, clf)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:289: ConvergenceWarning:
#
# Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# Training Accuracy:  0.9760411311053985
# Validation Accuracy:  0.5450809144618546

# %% [markdown]
# ### 2. PCA with Kernel

# %%
clf = svm.SVC(kernel='linear')
fun3(kernelpca_train_data, train_labels, kernelpca_validation_data, validation_labels, clf)
# Out:
# Training Accuracy:  0.2595372750642673
# Validation Accuracy:  0.27819162599537633

# %% [markdown]
# ### 3. LLE

# %%
fun3(lle_train_data, train_labels, lle_validation_data, validation_labels, clf)
# Out:
# Training Accuracy:  0.5726992287917738
# Validation Accuracy:  0.6198304649370665

# %% [markdown]
# ### 4. t-SNE

# %%
fun3(tsne_train_data, train_labels, tsne_validation_data, validation_labels, clf)
# Out:
# Training Accuracy:  0.9714652956298201
# Validation Accuracy:  0.6182892370922168
